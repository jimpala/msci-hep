# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import seaborn as sns

# %%
df_2jet2fold = pd.DataFrame.from_csv('gs_BDT_2jet2fold.csv')
df_2jet2fold[df_2jet2fold.param_base_estimator__max_depth == 3]
# Out:
#      mean_fit_time  mean_score_time  mean_test_score  mean_train_score  \
# 65        3.417184         0.101655         1.838319         67.644760
# 66        4.274156         0.097345         1.837160         67.842647
# 67        4.161355         0.096826         1.841903         67.985646
# 68        6.020993         0.139563         1.866681         68.475197
# 69        5.374907         0.110928         1.877285         68.079014
# 70        7.177115         0.117272         1.881367         68.194106
# 71        7.691967         0.122829         1.867829         68.730275
# 72        8.111951         0.132504         1.882852         68.846626
# 73        8.147211         0.138045         1.909629         68.867840
# 74        8.499645         0.141084         1.896416         68.800365
# 75       10.200706         0.288831         1.899183         69.014289
# 76       10.043121         0.184835         1.896795         68.881269
# ...

# %%
x = range(100)
y = range(100,200)
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(x[:4], y[:4], s=10, c='b', marker="s", label='first')
ax1.scatter(x[40:],y[40:], s=10, c='r', marker="o", label='second')
plt.legend(loc='upper left');
plt.show()

# %%
scores_2depth = df_2jet2fold[df_2jet2fold['param_base_estimator__max_depth'] == 2]['mean_test_score'].as_matrix()
scores_3depth = df_2jet2fold[df_2jet2fold['param_base_estimator__max_depth'] == 3]['mean_test_score'].as_matrix()
scores_4depth = df_2jet2fold[df_2jet2fold['param_base_estimator__max_depth'] == 4]['mean_test_score'].as_matrix()
scores_5depth = df_2jet2fold[df_2jet2fold['param_base_estimator__max_depth'] == 5]['mean_test_score'].as_matrix()


scores = np.vstack((scores_5depth, scores_4depth, scores_3depth, scores_2depth))
scores
# Out:
# array([[ 1.83722324,  1.84331338,  1.84929125,  1.85241598,  1.84801085,
#          1.85448561,  1.85257496,  1.85179354,  1.84999429,  1.84178408,
#          1.8436922 ,  1.84555579,  1.84188163,  1.83717846,  1.85057765,
#          1.84154844,  1.84017063,  1.84279765,  1.8493199 ,  1.85038823,
#          1.85739645,  1.85223855,  1.85204078,  1.85337288,  1.8503627 ,
#          1.85319721,  1.85003162,  1.85407829,  1.84426812,  1.83892227,
#          1.83695549,  1.84219905,  1.85022919,  1.84654552,  1.85142732,
#          1.85445682,  1.8537336 ,  1.85444258,  1.85422124,  1.85518613,
#          1.8450495 ,  1.85411043,  1.85314274,  1.85774686,  1.85619233,
#          1.84542876,  1.84319343,  1.84527577,  1.84806023,  1.84777202,
#          1.85228275,  1.83584366,  1.83839978,  1.833575  ,  1.83322448,
#          1.84033726,  1.83129934,  1.83895949,  1.83558214,  1.8321023 ,
#          1.83420556,  1.83585105,  1.83066821,  1.83193743,  1.83332581],
# ...

# %%
fig, ax = plt.subplots(figsize=(15,2))
cmap2 = sns.light_palette("green", as_cmap=True)

# rcParams
mpl.rcParams['axes.titlesize'] = 16.
mpl.rcParams['axes.titleweight'] = 'bold'


ax.imshow(scores, cmap=cmap2,
          interpolation='none', extent=[50,700,2,6], aspect='auto')
ax.set_xticks(np.arange(50, 701, 10))
ax.set_yticks(np.arange(2, 6.1, 1))

# Hide major tick labels
ax.set_xticklabels('')
ax.set_yticklabels('')


# Customize minor tick labels
ax.set_xticks(np.arange(55, 705, 50), minor=True)
ax.set_xticklabels(np.arange(50, 700, 50), minor=True)

# Customize minor tick labels
ax.set_yticks([2.5,3.5,4.5,5.5], minor=True)
ax.set_yticklabels(['2','3','4','5'], minor=True)

# Titles
ax.set_xlabel('Number of trees')
ax.set_ylabel('Maximum tree depth')
ax.set_title('Scikit BDT Hyperparameter Scan', loc='left')

    
plt.show()

# %%
mpl.rcParams['axes.titlesize']
# Out:
# 12.0
